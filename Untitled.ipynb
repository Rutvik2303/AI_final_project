# %% [markdown]
# <h1>AI final  project</h1>
# <br><h4>importing  dataset which is " train.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow import keras

# Load the dataset into a Pandas dataframe
df = pd.read_csv('test.csv')
print("data shape -:", df.shape)
# Out:
# data shape -: (25976, 25)

# %% [markdown]
# <h4>counting null values from whole data set

# %%
# Check for missing values
print(df.isnull().sum())

# Plot histograms of input features
df.hist(figsize=(12,15))
plt.show()

# Calculate output label distribution
label_counts = df['satisfaction'].value_counts()
print(label_counts)
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# Arrival Delay in Minutes             83
# satisfaction                          0
# dtype: int64
# neutral or dissatisfied    14573
# satisfied                  11403
# Name: satisfaction, dtype: int64

# %% [markdown]
# <h4>Here we are dropping two column because those are unnecessary like index and customer id
# <br><br>Secondly, I am mapping all string value in column to int like 0 and 1 as well as we are feeling all null with mean
# <br><br>And at the end normalize the data

# %%
df.drop(columns=['id','Unnamed: 0'], inplace=True)
df['Gender'].replace(['Male','Female'],[0,1],inplace=True)
df['Customer Type'].replace(['Loyal Customer','disloyal Customer'],[0,1],inplace=True)
df['Type of Travel'].replace(['Business travel','Personal Travel'],[0,1],inplace=True)
df['Class'].replace(['Eco','Business','Eco Plus'],[0,1,2],inplace=True)
df['satisfaction'].replace(['satisfied','neutral or dissatisfied',' '],[1,0,0],inplace=True)

# Normalize the data using Min-Max scaling

#scaler = MinMaxScaler()
df.fillna(df.mean(), inplace=True)

# fit and transform the data using the scaler
#clum=['Gender','Customer Type','Age','Type of Travel','Class','Flight Distance','Inflight wifi service','Departure/Arrival time convenient','Ease of Online booking','Gate location','Food and drink','Online boarding','Seat comfort','Inflight entertainment','On-board service','Leg room service','Baggage handling','Checkin service','Inflight service','Cleanliness','Departure Delay in Minutes','Arrival Delay in Minutes','satisfaction'] 
#for i in clum:
 #   df_norm[i]= scaler.fit_transform(df[i])
df_norm = (df - df.min()) / (df.max() - df.min())
df_norm = pd.DataFrame(df_norm)
# Re-plot histograms of input features after normalization
df_norm.hist(figsize=(15,15))
plt.show()
print(df_norm.isnull().sum())
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# <h2>Phase 2</h2>
# <h4>
# <br><br>here, we are trying to overfit the entire dataset with three different model
# <br><br>model 1:- 1,  epochs=100

# %%
# Load the dataset into a Pandas dataframe
df = df_norm

# Split the dataset into input features (X) and output labels (y)
x = df.drop('satisfaction', axis=1).values
y = df['satisfaction'].values


# Define a logistic regression model with one neuron
model = keras.Sequential([
    keras.layers.Dense(units=1, input_shape=[x.shape[1]])
])

# Compile the model with binary cross-entropy loss and Adam optimizer
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model for 100 epochs
history = model.fit(x, y, epochs=100, verbose=0)

# Plot the accuracy and loss curves during training
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['loss'], label='loss')
plt.legend()
plt.show()

# %% [markdown]
# <h4>model 2:- 2-1,  epochs=500

# %%
# Define a small neural network with 2 neurons in the input layer and 1 neuron in the output layer
model = keras.Sequential([
    keras.layers.Dense(units=2, input_shape=[x.shape[1]]),
    keras.layers.Dense(units=1)
])

# Compile the model with binary cross-entropy loss and Adam optimizer
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model for 1000 epochs
history = model.fit(x, y, epochs=500, verbose=0)

# Plot the accuracy and loss curves during training
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['loss'], label='loss')
plt.legend()
plt.show()

# %% [markdown]
# <h4>model 3:- 16-8-1,  epochs=1000

# %%
# Define a larger neural network with 16 neurons in the input layer, 8 neurons in the hidden layer, and 1 neuron in the output layer
model = keras.Sequential([
    keras.layers.Dense(units=32, input_shape=[x.shape[1]]),
    keras.layers.Dense(units=16, activation='relu'),
    keras.layers.Dense(units=8, activation='relu'),
    keras.layers.Dense(units=4, activation='relu'),
    keras.layers.Dense(units=1)
])

# Compile the model with binary cross-entropy loss and Adam optimizer
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model for 100 epochs
history = model.fit(x, y, epochs=100, verbose=0)

# Plot the accuracy and loss curves during training
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['loss'], label='loss')
plt.legend()
plt.show()

# %% [markdown]
# <h2>phase 3:</h2>
# <h4><br>
# here we are shuffling rows before split into training and validation sets.

# %%
# Load data
data = df
# Shuffle rows
data = data.sample(frac=1).reset_index(drop=True)

# Split data into training and validation sets
train_data = data.iloc[:int(0.8*len(data))]
val_data = data.iloc[int(0.8*len(data)):]

# Split features and labels
train_features = train_data.drop('satisfaction', axis=1)
train_labels = train_data['satisfaction']
val_features = val_data.drop('satisfaction', axis=1)
val_labels = val_data['satisfaction']

# Convert to numpy arrays
train_features = np.array(train_features)
train_labels = np.array(train_labels)
val_features = np.array(val_features)
val_labels = np.array(val_labels)

# Define the model
model1 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(2, activation='relu', input_shape=(22,)),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(6, activation='relu', input_shape=(22,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model3 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(22,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
from sklearn.model_selection import train_test_split
# Split the dataset into input features (X) and output labels (y)
x = df.drop('satisfaction', axis=1).values
y = df['satisfaction'].values


x_train, x_test, y_train, y_test = train_test_split(x,y ,random_state=104, test_size=0.20, shuffle=True)

# %%
# Out:
# 20780

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(2, activation='relu', input_shape=(22,)),
    tf.keras.layers.Dense(4, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model for 100 epochs
history = model.fit(x_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 650/650 [==============================] - 1s 688us/step - loss: 0.6281 - accuracy: 0.6938
# Epoch 2/100
# 650/650 [==============================] - 0s 690us/step - loss: 0.4205 - accuracy: 0.8371
# Epoch 3/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.3449 - accuracy: 0.8600
# Epoch 4/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.3289 - accuracy: 0.8663
# Epoch 5/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.3175 - accuracy: 0.8731
# Epoch 6/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.3062 - accuracy: 0.8813
# Epoch 7/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.2955 - accuracy: 0.8851
# Epoch 8/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.2847 - accuracy: 0.8897
# Epoch 9/100
# 650/650 [==============================] - 0s 676us/step - loss: 0.2750 - accuracy: 0.8945
# Epoch 10/100
# 650/650 [==============================] - 0s 691us/step - loss: 0.2653 - accuracy: 0.8982
# Epoch 11/100
# 650/650 [==============================] - 0s 702us/step - loss: 0.2569 - accuracy: 0.9020
# Epoch 12/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.2489 - accuracy: 0.9050
# Epoch 13/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.2420 - accuracy: 0.9062
# Epoch 14/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.2368 - accuracy: 0.9072
# Epoch 15/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.2317 - accuracy: 0.9072
# Epoch 16/100
# 650/650 [==============================] - 0s 700us/step - loss: 0.2277 - accuracy: 0.9092
# Epoch 17/100
# 650/650 [==============================] - 0s 661us/step - loss: 0.2243 - accuracy: 0.9111
# Epoch 18/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2215 - accuracy: 0.9116
# Epoch 19/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2186 - accuracy: 0.9126
# Epoch 20/100
# 650/650 [==============================] - 0s 676us/step - loss: 0.2164 - accuracy: 0.9124
# Epoch 21/100
# 650/650 [==============================] - 0s 667us/step - loss: 0.2145 - accuracy: 0.9135
# Epoch 22/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2124 - accuracy: 0.9141
# Epoch 23/100
# 650/650 [==============================] - 0s 687us/step - loss: 0.2105 - accuracy: 0.9155
# Epoch 24/100
# 650/650 [==============================] - 0s 642us/step - loss: 0.2091 - accuracy: 0.9156
# Epoch 25/100
# 650/650 [==============================] - 0s 652us/step - loss: 0.2074 - accuracy: 0.9158
# Epoch 26/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.
100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1834 - accuracy: 0.9238
# Epoch 76/100
# 650/650 [==============================] - 0s 628us/step - loss: 0.1832 - accuracy: 0.9252
# Epoch 77/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1832 - accuracy: 0.9245
# Epoch 78/100
# 650/650 [==============================] - 0s 708us/step - loss: 0.1828 - accuracy: 0.9249
# Epoch 79/100
# 650/650 [==============================] - 0s 694us/step - loss: 0.1827 - accuracy: 0.9243
# Epoch 80/100
# 650/650 [==============================] - 0s 695us/step - loss: 0.1830 - accuracy: 0.9259
# Epoch 81/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1824 - accuracy: 0.9246
# Epoch 82/100
# 650/650 [==============================] - 0s 708us/step - loss: 0.1822 - accuracy: 0.9254
# Epoch 83/100
# 650/650 [==============================] - 0s 694us/step - loss: 0.1820 - accuracy: 0.9247
# Epoch 84/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1826 - accuracy: 0.9254
# Epoch 85/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1824 - accuracy: 0.9260
# Epoch 86/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1818 - accuracy: 0.9247
# Epoch 87/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1815 - accuracy: 0.9262
# Epoch 88/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1816 - accuracy: 0.9242
# Epoch 89/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1818 - accuracy: 0.9260
# Epoch 90/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1815 - accuracy: 0.9248
# Epoch 91/100
# 650/650 [==============================] - 0s 682us/step - loss: 0.1817 - accuracy: 0.9253
# Epoch 92/100
# 650/650 [==============================] - 0s 695us/step - loss: 0.1811 - accuracy: 0.9263
# Epoch 93/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1814 - accuracy: 0.9260
# Epoch 94/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1808 - accuracy: 0.9258
# Epoch 95/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1810 - accuracy: 0.9264
# Epoch 96/100
# 650/650 [==============================] - 0s 700us/step - loss: 0.1810 - accuracy: 0.9260
# Epoch 97/100
# 650/650 [==============================] - 0s 629us/step - loss: 0.1801 - accuracy: 0.9273
# Epoch 98/100
# 650/650 [==============================] - 0s 635us/step - loss: 0.1807 - accuracy: 0.9256
# Epoch 99/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1810 - accuracy: 0.9266
# Epoch 100/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1803 - accuracy: 0.9260

# %%
hypothesis = model.predict(x_test)

# Let's get the accuracy
validation_accuracy = model.evaluate(x_test, y_test)
# Out:
# 163/163 [==============================] - 0s 481us/step
# 163/163 [==============================] - 0s 581us/step - loss: 0.1809 - accuracy: 0.9278

# %%
len(x_train[0])
# Out:
# 22

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(6, activation='relu', input_shape=(len(x_train[0]),)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model for 100 epochs
history = model.fit(x_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 650/650 [==============================] - 1s 653us/step - loss: 0.5102 - accuracy: 0.7609
# Epoch 2/100
# 650/650 [==============================] - 0s 629us/step - loss: 0.3474 - accuracy: 0.8616
# Epoch 3/100
# 650/650 [==============================] - 0s 628us/step - loss: 0.3231 - accuracy: 0.8714
# Epoch 4/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.3105 - accuracy: 0.8764
# Epoch 5/100
# 650/650 [==============================] - 0s 689us/step - loss: 0.3009 - accuracy: 0.8790
# Epoch 6/100
# 650/650 [==============================] - 0s 628us/step - loss: 0.2929 - accuracy: 0.8810
# Epoch 7/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2860 - accuracy: 0.8817
# Epoch 8/100
# 650/650 [==============================] - 0s 654us/step - loss: 0.2785 - accuracy: 0.8836
# Epoch 9/100
# 650/650 [==============================] - 0s 629us/step - loss: 0.2718 - accuracy: 0.8850
# Epoch 10/100
# 650/650 [==============================] - 0s 628us/step - loss: 0.2652 - accuracy: 0.8868
# Epoch 11/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2594 - accuracy: 0.8912
# Epoch 12/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.2538 - accuracy: 0.8937
# Epoch 13/100
# 650/650 [==============================] - 0s 654us/step - loss: 0.2490 - accuracy: 0.8966
# Epoch 14/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2434 - accuracy: 0.8976
# Epoch 15/100
# 650/650 [==============================] - 0s 626us/step - loss: 0.2380 - accuracy: 0.9016
# Epoch 16/100
# 650/650 [==============================] - 0s 654us/step - loss: 0.2322 - accuracy: 0.9025
# Epoch 17/100
# 650/650 [==============================] - 0s 652us/step - loss: 0.2260 - accuracy: 0.9060
# Epoch 18/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2189 - accuracy: 0.9094
# Epoch 19/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.2125 - accuracy: 0.9132
# Epoch 20/100
# 650/650 [==============================] - 0s 652us/step - loss: 0
100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1416 - accuracy: 0.9403
# Epoch 77/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1403 - accuracy: 0.9406
# Epoch 78/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1410 - accuracy: 0.9412
# Epoch 79/100
# 650/650 [==============================] - 0s 652us/step - loss: 0.1407 - accuracy: 0.9415
# Epoch 80/100
# 650/650 [==============================] - 0s 667us/step - loss: 0.1408 - accuracy: 0.9405
# Epoch 81/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1403 - accuracy: 0.9399
# Epoch 82/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1406 - accuracy: 0.9402
# Epoch 83/100
# 650/650 [==============================] - 0s 710us/step - loss: 0.1405 - accuracy: 0.9401
# Epoch 84/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1395 - accuracy: 0.9415
# Epoch 85/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1391 - accuracy: 0.9412
# Epoch 86/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1396 - accuracy: 0.9410
# Epoch 87/100
# 650/650 [==============================] - 0s 686us/step - loss: 0.1392 - accuracy: 0.9403
# Epoch 88/100
# 650/650 [==============================] - 0s 667us/step - loss: 0.1393 - accuracy: 0.9409
# Epoch 89/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1396 - accuracy: 0.9404
# Epoch 90/100
# 650/650 [==============================] - 0s 663us/step - loss: 0.1389 - accuracy: 0.9418
# Epoch 91/100
# 650/650 [==============================] - 0s 666us/step - loss: 0.1387 - accuracy: 0.9420
# Epoch 92/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1393 - accuracy: 0.9407
# Epoch 93/100
# 650/650 [==============================] - 0s 665us/step - loss: 0.1383 - accuracy: 0.9419
# Epoch 94/100
# 650/650 [==============================] - 0s 629us/step - loss: 0.1381 - accuracy: 0.9424
# Epoch 95/100
# 650/650 [==============================] - 0s 654us/step - loss: 0.1378 - accuracy: 0.9414
# Epoch 96/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1380 - accuracy: 0.9406
# Epoch 97/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1383 - accuracy: 0.9410
# Epoch 98/100
# 650/650 [==============================] - 0s 652us/step - loss: 0.1378 - accuracy: 0.9421
# Epoch 99/100
# 650/650 [==============================] - 0s 629us/step - loss: 0.1376 - accuracy: 0.9419
# Epoch 100/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1367 - accuracy: 0.9424

# %%
hypothesis = model.predict(x_test)

# Let's get the accuracy
validation_accuracy = model.evaluate(x_test, y_test)
# Out:
# 163/163 [==============================] - 0s 485us/step
# 163/163 [==============================] - 0s 581us/step - loss: 0.1464 - accuracy: 0.9403

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(len(x_train[0]),)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model for 100 epochs
history = model.fit(x_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 650/650 [==============================] - 1s 704us/step - loss: 0.4401 - accuracy: 0.8018
# Epoch 2/100
# 650/650 [==============================] - 0s 674us/step - loss: 0.3352 - accuracy: 0.8649
# Epoch 3/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.3151 - accuracy: 0.8726
# Epoch 4/100
# 650/650 [==============================] - 0s 676us/step - loss: 0.2975 - accuracy: 0.8786
# Epoch 5/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2805 - accuracy: 0.8832
# Epoch 6/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2615 - accuracy: 0.8885
# Epoch 7/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.2395 - accuracy: 0.9005
# Epoch 8/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.2207 - accuracy: 0.9121
# Epoch 9/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.2078 - accuracy: 0.9167
# Epoch 10/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1991 - accuracy: 0.9211
# Epoch 11/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1915 - accuracy: 0.9236
# Epoch 12/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1857 - accuracy: 0.9252
# Epoch 13/100
# 650/650 [==============================] - 0s 725us/step - loss: 0.1811 - accuracy: 0.9282
# Epoch 14/100
# 650/650 [==============================] - 0s 725us/step - loss: 0.1741 - accuracy: 0.9298
# Epoch 15/100
# 650/650 [==============================] - 0s 700us/step - loss: 0.1691 - accuracy: 0.9314
# Epoch 16/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1657 - accuracy: 0.9327
# Epoch 17/100
# 650/650 [==============================] - 0s 701us/step - loss: 0.1615 - accuracy: 0.9342
# Epoch 18/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1590 - accuracy: 0.9360
# Epoch 19/100
# 650/650 [==============================] - 0s 676us/step - loss: 0.1551 - accuracy: 0.9365
# Epoch 20/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1536 - accuracy: 0.9371
# Epoch 21/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.
100
# 650/650 [==============================] - 0s 652us/step - loss: 0.1295 - accuracy: 0.9446
# Epoch 74/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1300 - accuracy: 0.9441
# Epoch 75/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1302 - accuracy: 0.9433
# Epoch 76/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1296 - accuracy: 0.9438
# Epoch 77/100
# 650/650 [==============================] - 0s 652us/step - loss: 0.1295 - accuracy: 0.9444
# Epoch 78/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1289 - accuracy: 0.9449
# Epoch 79/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1297 - accuracy: 0.9444
# Epoch 80/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1295 - accuracy: 0.9438
# Epoch 81/100
# 650/650 [==============================] - 0s 662us/step - loss: 0.1287 - accuracy: 0.9444
# Epoch 82/100
# 650/650 [==============================] - 0s 667us/step - loss: 0.1294 - accuracy: 0.9432
# Epoch 83/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1280 - accuracy: 0.9450
# Epoch 84/100
# 650/650 [==============================] - 0s 663us/step - loss: 0.1300 - accuracy: 0.9454
# Epoch 85/100
# 650/650 [==============================] - 0s 666us/step - loss: 0.1285 - accuracy: 0.9446
# Epoch 86/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1280 - accuracy: 0.9450
# Epoch 87/100
# 650/650 [==============================] - 0s 628us/step - loss: 0.1281 - accuracy: 0.9442
# Epoch 88/100
# 650/650 [==============================] - 0s 654us/step - loss: 0.1274 - accuracy: 0.9459
# Epoch 89/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1286 - accuracy: 0.9441
# Epoch 90/100
# 650/650 [==============================] - 0s 676us/step - loss: 0.1276 - accuracy: 0.9449
# Epoch 91/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1280 - accuracy: 0.9445
# Epoch 92/100
# 650/650 [==============================] - 0s 652us/step - loss: 0.1281 - accuracy: 0.9443
# Epoch 93/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1278 - accuracy: 0.9448
# Epoch 94/100
# 650/650 [==============================] - 0s 676us/step - loss: 0.1277 - accuracy: 0.9445
# Epoch 95/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1277 - accuracy: 0.9456
# Epoch 96/100
# 650/650 [==============================] - 0s 653us/step - loss: 0.1285 - accuracy: 0.9441
# Epoch 97/100
# 650/650 [==============================] - 0s 658us/step - loss: 0.1277 - accuracy: 0.9450
# Epoch 98/100
# 650/650 [==============================] - 0s 652us/step - loss: 0.1264 - accuracy: 0.9462
# Epoch 99/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1260 - accuracy: 0.9464
# Epoch 100/100
# 650/650 [==============================] - 0s 677us/step - loss: 0.1274 - accuracy: 0.9446

# %%
hypothesis = model.predict(x_test)

# Let's get the accuracy
validation_accuracy = model.evaluate(x_test, y_test)
# Out:
# 163/163 [==============================] - 0s 485us/step
# 163/163 [==============================] - 0s 581us/step - loss: 0.1405 - accuracy: 0.9400

# %% [markdown]
# <h2>Phase 4:</h2>
# <h4><br>
# we are using one feture at the time to train the model to find importence on each feture in our dataset

# %%
clum=df.columns

# %%
for i in range(len(clum)-1):
    x = df[clum[i]].values
    y = df['satisfaction'].values
    x_train, x_test, y_train, y_test = train_test_split(x,y ,random_state=0, test_size=0.20, shuffle=False )
    
    model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train, y_train, epochs=100, verbose=0)
    hypothesis = model.predict(x_test)
    print("validation_accuracy for--: "+ clum[i])
    # Let's get the accuracy
    validation_accuracy = model.evaluate(x_test, y_test)
# Out:
# 163/163 [==============================] - 0s 494us/step
# validation_accuracy for--: Gender
# 163/163 [==============================] - 0s 557us/step - loss: 0.6871 - accuracy: 0.5554
# 163/163 [==============================] - 0s 492us/step
# validation_accuracy for--: Customer Type
# 163/163 [==============================] - 0s 555us/step - loss: 0.6871 - accuracy: 0.5554
# 163/163 [==============================] - 0s 492us/step
# validation_accuracy for--: Age
